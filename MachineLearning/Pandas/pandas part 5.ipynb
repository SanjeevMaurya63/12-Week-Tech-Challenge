# %% [markdown]
# 1.Read XML and get Dataframe
# 2.Convert Dataframe to XML

# %%
import pandas as pd

# %%
pd.read_xml('Unconfirmed 608718.crdownload')
# Out:
#          name  degrees  sides
# 0    Pentagon      540      5
# 1     Octagon     1080      8
# 2     Nonagon     1260      9
# 3      Square      360      4
# 4      Square      360      4
# ..        ...      ...    ...
# 495   Nonagon     1260      9
# 496   Decagon     1440     10
# 497  Heptagon      900      7
# 498   Nonagon     1260      9
# 499    Square      360      4
#
# [500 rows x 3 columns]

# %%
xml= '''<?xml version='1.0' encoding='utf-8'?>

<shapes><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Rectangle</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Triangle</name><degrees>180</degrees><sides>3</sides></shape><shape><name>Hexagon</name><degrees>720</degrees><sides>6</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Octagon</name><degrees>1080</degrees><sides>8</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape><shape><name>Pentagon</name><degrees>540</degrees><sides>5</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides></shape><shape><name>Decagon</name><degrees>1440</degrees><sides>10</sides></shape><shape><name>Heptagon</name><degrees>900</degrees><sides>7</sides></shape><shape><name>Nonagon</name><degrees>1260</degrees><sides>9</sides><firstname>sanjeev</firstname></shape><shape><name>Square</name><degrees>360</degrees><sides>4</sides></shape></shapes>
'''

# %%
pd.read_xml(xml)  #maine data set ma firstname ka colom add kiya h bo sikha h kaise  add krte h
# Out:
# C:\Users\Sanjeev\AppData\Local\Temp\ipykernel_7448\2704978085.py:1: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_xml(xml)
#          name  degrees  sides firstname
# 0    Pentagon      540      5      None
# 1     Octagon     1080      8      None
# 2     Nonagon     1260      9      None
# 3      Square      360      4      None
# 4      Square      360      4      None
# ..        ...      ...    ...       ...
# 495   Nonagon     1260      9      None
# 496   Decagon     1440     10      None
# 497  Heptagon      900      7      None
# 498   Nonagon     1260      9   sanjeev
# 499    Square      360      4      None
#
# [500 rows x 4 columns]

# %%
df=pd.read_xml(xml,xpath=".//shape")
# Out:
# C:\Users\Sanjeev\AppData\Local\Temp\ipykernel_7448\3161722032.py:1: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_xml(xml,xpath=".//shape")
#          name  degrees  sides firstname
# 0    Pentagon      540      5      None
# 1     Octagon     1080      8      None
# 2     Nonagon     1260      9      None
# 3      Square      360      4      None
# 4      Square      360      4      None
# ..        ...      ...    ...       ...
# 495   Nonagon     1260      9      None
# 496   Decagon     1440     10      None
# 497  Heptagon      900      7      None
# 498   Nonagon     1260      9   sanjeev
# 499    Square      360      4      None
#
# [500 rows x 4 columns]

# %%
df.to_xml('test.xml')
